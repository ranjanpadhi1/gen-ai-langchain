# %% [markdown]
# ## Document Loaders

# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader, WebBaseLoader, WikipediaLoader

# %% [markdown]
# #### Text Loader

# %%
loader = TextLoader('../files/gen_ai.txt')
docs = loader.load()
docs[0].page_content
# Out:
# 'Generative artificial intelligence (generative AI, GenAI,[1] or GAI) is artificial intelligence capable of generating text, images, videos, or other data using generative models,[2] often in response to prompts.[3][4] Generative AI models learn the patterns and structure of their input training data and then generate new data that has similar characteristics.[5][6]\n\nImprovements in transformer-based deep neural networks, particularly large language models (LLMs), enabled an AI boom of generative AI systems in the early 2020s. These include chatbots such as ChatGPT, Copilot, Gemini and LLaMA, text-to-image artificial intelligence image generation systems such as Stable Diffusion, Midjourney and DALL-E, and text-to-video AI generators such as Sora.[7][8][9][10] Companies such as OpenAI, Anthropic, Microsoft, Google, and Baidu as well as numerous smaller firms have developed generative AI models.[3][11][12]\n\nGenerative AI has uses across a wide range of industries, including softwa
# ...

# %% [markdown]
# #### PDF Loader

# %%
loader = PyPDFLoader('../files/BOOKING_INVOICE.pdf')
docs = loader.load()
docs[0].page_content
# Out:
# 'BOOKING ID:\nNF74JW6GU0QCZ2WK7818\nINVOICE NO.\nM06AI24I22900895\nDATE:\n31/03/2024\nTRANSACTIONAL TYPE/CATEGORY:\nB2C/REG\nDOCUMENT TYPE:\nINVOICE\nTRANSACTION DETAIL:\nRG\nPLACE OF SUPPLY\nKarnataka\nINR 14164.0\n*Fare charges\n(including applicable flight taxes collected on behalf of airline & other ancillary\ncharges)\nINR 13685.0\nMakeMyTrip Service\nFees\nINR 405.93\nIGST @ 18%\nINR 73.07\nTAX INVOICE\n6E\n \n6E - 405\nBLR \n-\n RPR \n09-05-2024\nTrupti Ranjan \nPadhi \n(PNR: M1F67Q) (Ticket No: M1F67Q ) \n6E\n \n6E - 979\nRPR \n-\n BLR \n12-05-2024\nTrupti Ranjan \nPadhi \n(PNR: R12C5D) (Ticket No: R12C5D ) \nCUSTOMER NAME\nTrupti Ranjan \nPadhi\nBOOKED BY\nRanjan \nPadhi\nINVOICE ISSUED FOR FLIGHT\nPAYMENT BREAKUP\nTotal Booking Amount\nThis is a computer generated Invoice and does not require Signature/Stamp.\nGST credit charged by the airline operator is only available against the invoice issued by the respective airline operator. If you\nare looking for the airline GST in
# ...

# %% [markdown]
# #### Web-based Loader

# %%
loader = WebBaseLoader(web_path='https://en.wikipedia.org/wiki/Husky')
docs = loader.load()
docs[0].page_content
# Out:
# '\n\n\n\nHusky - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nHistory\n\n\n\n\n\n\n\n\n2\nEtymology\n\n\n\n\n\n\n\n\n3\nCharacteristics\n\n\n\n\n\n\n\n\n4\nBreeds\n\n\n\n\nToggle Breeds subsection\n\n\n\n\n\n4.1\nAlaska
# ...

# %% [markdown]
# #### Wikipedia Loader

# %%
loader = WikipediaLoader(query='Gen AI', load_max_docs=2)
docs = loader.load()
docs[0]
# Out:
# Document(metadata={'title': 'Generative artificial intelligence', 'summary': 'Generative artificial intelligence (generative AI, GenAI, or GAI) is artificial intelligence capable of generating text, images, videos, or other data using generative models, often in response to prompts. Generative AI models learn the patterns and structure of their input training data and then generate new data that has similar characteristics. \nImprovements in transformer-based deep neural networks, particularly large language models (LLMs), enabled an AI boom of generative AI systems in the early 2020s. These include chatbots such as ChatGPT, Copilot, Gemini and LLaMA, text-to-image artificial intelligence image generation systems such as Stable Diffusion, Midjourney and DALL-E, and text-to-video AI generators such as Sora. Companies such as OpenAI, Anthropic, Microsoft, Google, and Baidu as well as numerous smaller firms have developed generative AI models.\nGenerative AI has uses across a wide range
# ...
